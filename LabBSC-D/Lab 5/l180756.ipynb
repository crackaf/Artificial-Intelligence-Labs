# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("adult.data.csv")

# %%
 data
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
gender=data['sex']
temp=(gender.value_counts())
print("Number of Males = ",temp["Male"])
print("Number of Males = ", temp["Female"])
# Out:
# Number of Males =  21790
# Number of Males =  10771

# %%
dt=data.groupby('sex', as_index=False).age.mean()
print("Average age of Females is: ",dt.loc[0][1])
# Out:
# Average age of Females is:  36.85823043357163

# %%
dt=data['native-country']
numUS=dt.value_counts()
print("Number of US citizens: ",numUS["United-States"])
# Out:
# Number of US citizens:  29170

# %%
less=data.loc[data['salary'] == '<=50K']
greater=data.loc[data['salary']=='>50K']
# print(less)
print("Mean value of age with salary less than 50K: " ,less.mean()['age'])
print("Standard deviation of age with salary less than 50K: ",less.std()['age'])
print("Mean value of age with salary greater than 50K: " ,greater.mean()['age'])
print("Standard deviation of age with salary greater than 50K: ",greaBter.std()['age'])
# print(greater)
# Out:
# Mean value of age with salary less than 50K:  36.78373786407767
# Standard deviation of age with salary less than 50K:  14.020088490824813
# Mean value of age with salary greater than 50K:  44.24984058155847
# Standard deviation of age with salary greater than 50K:  10.51902771985177

# %%
education=data.loc[data['salary'] == '>50K']
education=education.loc[education['education-num']<11]
if len(education.index)>0:
    print("No.")
else:
    print("Yes.")
# Out:
# No.

# %%
dt=pd.DataFrame(data.groupby(['race','sex']).age.describe())
print(dt)
dt=pd.DataFrame(data.loc[data['race']=='Amer-Indian-Eskimo'])
dt=pd.DataFrame(dt.loc[dt['sex']=='Male'])
print("Max age for Amer-Indian-Eskimo men is",dt['age'].max())
# Out:
#                              count       mean        std   min   25%   50%  \
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
#                    Male    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                              75%   max
# race               sex
# Amer-Indian-Eskimo Female  46.00  80.0
# ...

# %%
married=data.loc[(data['sex'] == 'Male') & (data['marital-status'].str.startswith('Married')), 'salary'].value_counts()['>50K']
print("Earning of married men is:",married)
dt=data.loc[(data['sex']=='Male')]
unmarried=dt.loc[(dt['marital-status']).apply(lambda st: not(st.startswith('Married')))]
unmarried=unmarried.loc[(dt['salary']==">50K")]
print("Earning of unmarried men is:",len(unmarried.index))
# Out:
# Earning of married men is: 5965
# Earning of unmarried men is: 697

# %%
max_hours = data['hours-per-week'].max()
print("Max time is {0} hours per week.".format(max_hours))

max_workers = len(data[data['hours-per-week'] == max_hours].index)

print("Total number of such hard workers {0}".format(max_workers))

rich_earning = float(len(data[(data['hours-per-week'] == max_hours)
                 & (data['salary'] == '>50K')].index)) / max_workers
print("Percentage of rich among them {0}%".format(int(100 * rich_earning)))
# Out:
# Max time is 99 hours per week.
# Total number of such hard workers 85
# Percentage of rich among them 29%

# %%
pd.crosstab(data['native-country'], data['salary'], 
           values=data['hours-per-week'], aggfunc=np.mean)
# Out:
# salary                          <=50K       >50K
# native-country
# ?                           40.164760  45.547945
# Cambodia                    41.416667  40.000000
# Canada                      37.914634  45.641026
# China                       37.381818  38.900000
# Columbia                    38.684211  50.000000
# Cuba                        37.985714  42.440000
# Dominican-Republic          42.338235  47.000000
# Ecuador                     38.041667  48.750000
# El-Salvador                 36.030928  45.000000
# England                     40.483333  44.533333
# France                      41.058824  50.750000
# Germany                     39.139785  44.977273
# Greece                      41.809524  50.625000
# Guatemala                   39.360656  36.666667
# Haiti                       36.325000  42.750000
# Holand-Netherlands          40.000000        NaN
# Honduras                    34.333333  60.000000
# Hong                        39.142857  45.000000
# ...
